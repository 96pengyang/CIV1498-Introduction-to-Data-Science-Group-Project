# %% [markdown]
# # CIV1499 - Introduction to Data Science
# ## Project - Toronto Bike Share

# %% [markdown]
# ## Setup Notebook

# %%
# Import 3rd party libraries
import os
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np
from fuzzywuzzy import fuzz

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Station Data

# %%
# Import bikeshare stations
stations = pd.read_csv('bikeshare_stations.csv')
stations.head()
# Out:
#    Station Id                     Station Name        lat        lon  capacity
# 0        7000     Fort York  Blvd / Capreol Ct  43.639832 -79.395954        35
# 1        7001  Lower Jarvis St / The Esplanade  43.647830 -79.370698        15
# 2        7002       St. George St / Bloor St W  43.667333 -79.399429        19
# 3        7003         Madison Ave / Bloor St W  43.667158 -79.402761        15
# 4        7004          University Ave / Elm St  43.656518 -79.389099        11

# %%
# Check if missing values exist
stations.isnull().sum()
# Out:
# Station Id      0
# Station Name    0
# lat             0
# lon             0
# capacity        0
# dtype: int64

# %% [markdown]
# # 2. Bike Share Trip Data

# %% [markdown]
# ## 2019 Data
# Task to be done:
# - load all the 2019 bike share csv files and combine them in a DataFrame
# - modify time columns and change the time zone to EST
# - check the missing values

# %%
################### TASK 1 #############################
# Import bike share data of 2019
trips_filenames_2019 = [filename for filename in os.listdir() if 'bike_share_2019' in filename]
dfs = []
for i in trips_filenames_2019 :
    data =  pd.read_csv(i)
    dfs.append(data)
trips_data_2019 = pd.concat(dfs,axis=0,ignore_index=True)

#remove double spaces from the column names
trips_data_2019.columns = [' '.join(col.split()) for col in trips_data_2019.columns]              

################# TASK 2 ##############################
# localize and convert time zone
#drop the EST in the bracket, localize and convert the time in EST
est_list = []
for i in pd.DatetimeIndex(pd.to_datetime(trips_data_2019['Start Time'].map(lambda x: str(x)[:-6]),dayfirst=True)):
    est_list.append(i.tz_localize("EST"))
trips_data_2019["Start Time"] = est_list

# Drop the EST in the bracket of end time, localize and convert the time in EST
est_list = []
for i in pd.DatetimeIndex(pd.to_datetime(trips_data_2019['End Time'].map(lambda x: str(x)[:-6]),dayfirst=True)):
    est_list.append(i.tz_localize("EST"))
trips_data_2019["End Time"] = est_list

# View DataFrame
trips_data_2019.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0  4581278           199751           1547              7021
# 1  4581279           294730           1112              7160
# 2  4581280           197252            589              7055
# 3  4581281           171700            259              7012
# 4  4581282           306314            281              7041
#
#                  Start Time                       Start Station Name  \
# 0 2019-01-01 00:08:00-05:00                       Bay St / Albert St
# 1 2019-01-01 00:10:00-05:00                 King St W / Tecumseth St
# 2 2019-01-01 00:15:00-05:00                   Jarvis St / Carlton St
# 3 2019-01-01 00:16:00-05:00  Elizabeth St / Edward St (Bus Terminal)
# 4 2019-01-01 00:19:00-05:00                     Edward St / Yonge St
#
#    End Station Id                  End Time  \
# 0          7233.0 2019-01-01 00:33:00-05:00
# 1          7051.0 2019-01-01 00:29:00-05:00
# 2          7013.0 2019-01-01 00:25:00-05:00
# 3          7235.0 2019-01-01 00:20:00-05:00
# 4          7257.0 2019-01-01 00:24:00-05:00
#
#                           End Station Name  Bike Id      User Type
# 0                 King / Cowan Ave - SMART     1296  Annual Member
# 1      Wellesley St E / Yonge St (Green P)     2947  Annual Member
# 2                 Scott St / The Esplanade     2293  Annual Member
# 3  Bay St / College St (West Side) - SMART      283  Annual Member
# 4             Dundas St W / St. Patrick St     1799  Annual Member

# %%
################# TASK 3 ##############################
# Check missing values
trips_data_2019.isnull().sum()
# Out:
# Trip Id                 0
# Subscription Id         0
# Trip Duration           0
# Start Station Id        0
# Start Time              0
# Start Station Name      0
# End Station Id        454
# End Time                0
# End Station Name      454
# Bike Id                 0
# User Type               0
# dtype: int64

# %% [markdown]
# Before investgating those missing values, lets drop those rows which duration is shorter than 60s and use statistics to eliminate outliers.

# %%
def outliers_eliminate(data):
    """
    This function is used to eliminate those duration outliers in the dataset
    """
    # Narrow down our dataset with 60 seconds duration filter
    data =data[data["Trip Duration"]>=60]
    
    # Compute quartiles
    Q1 =data ["Trip Duration"].quantile(0.25)
    Q3 =data ["Trip Duration"].quantile(0.75)
    IQR = Q3 - Q1
    data  = data [data ["Trip Duration"]<=(Q3+1.5*IQR)]
    data  = data [data ["Trip Duration"]>=(Q1-1.5*IQR)]
    return data

# %%
trips_data_2019 = outliers_eliminate(trips_data_2019)

# %% [markdown]
# Investigation on those rows with missing ID

# %%
#Those trips without destination station name and ID
trips_data_2019[trips_data_2019["End Station Id"].isnull()==True].head()
# Out:
#        Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 61656  6795174           477797           1676              7425
# 62796  6796528           310361            674              7070
# 63105  6796906           407387            840              7347
# 64839  6799037           363468            713              7317
# 66860  6801398           448729           1627              7299
#
#                      Start Time                       Start Station Name  \
# 61656 2019-10-01 06:07:00-05:00  The Queensway at South Kingsway - SMART
# 62796 2019-10-01 08:20:00-05:00         25 York St – Union Station South
# 63105 2019-10-01 08:34:00-05:00                   Regal Rd / Dufferin St
# 64839 2019-10-01 10:07:00-05:00                 Hubbard Blvd / Balsam Av
# 66860 2019-10-01 14:33:00-05:00                  Mill St / Parliament St
#
#        End Station Id                  End Time End Station Name  Bike Id  \
# 61656             NaN 2019-10-01 06:35:00-05:00              NaN     2133
# 62796             NaN 2019-10-01 08:31:00-05:00              NaN     4656
# 63105             NaN 2019-10-01 08:48:00-05:00              NaN     1328
# 64839             NaN 2019-10-01 10:19:00-05:00              NaN     4073
# 66860             NaN 2019-10-01 15:00:00-05:00              NaN     2063
#
#            User Type
# 61656  Annual Member
# 62796  Annual Member
# 63105  Annual Member
# 64839  Annual Member
# 66860  Annual Member

# %% [markdown]
# Conparing to the entire dataset, dropping 454 rows would not cause much information loss. In this case, one appropriate method is to remove those rows without End ID and Name.

# %%
# Remove those rows with missing ID values
trips_data_2019 = trips_data_2019[trips_data_2019["End Station Id"].isnull()==False]

# %% [markdown]
# ## 2020 Data
# Task to be done:
# - load all the 2020 bike share csv files and combine them in a DataFrame
# - modify time columns and change the time zone to EST
# - check the missing values

# %%
################### TASK 1 #############################
# Import data 2020
trips_filenames_2020 = [filename for filename in os.listdir() if 'bike_share_2020' in filename]
dfs = []
for i in trips_filenames_2020 :
    data =  pd.read_csv(i)
    dfs.append(data)
trips_data_2020 = pd.concat(dfs,axis=0,ignore_index=True)

# Remove double spaces from the column names
trips_data_2020.columns = [' '.join(col.split()) for col in trips_data_2020.columns]              

################# TASK 2 ##############################
# localize and convert time zone
# Drop the EST in the bracket
est_list = []
for i in pd.DatetimeIndex(pd.to_datetime(trips_data_2020['Start Time'].map(lambda x: str(x)[:-6]),dayfirst=True)):
    est_list.append(i.tz_localize("EST"))
trips_data_2020["Start Time"] = est_list
est_list = []
for i in pd.DatetimeIndex(pd.to_datetime(trips_data_2020['End Time'].map(lambda x: str(x)[:-6]),dayfirst=True)):
    est_list.append(i.tz_localize("EST"))
trips_data_2020["End Time"] = est_list

# View DataFrame
trips_data_2020.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0  7334128           324700            648              7003
# 1  7334129           350579            419              7007
# 2  7334130           438337            566              7113
# 3  7334131           452126           1274              7333
# 4  7334132           523945            906              7009
#
#                  Start Time            Start Station Name  End Station Id  \
# 0 2020-01-01 00:08:00-05:00      Madison Ave / Bloor St W          7271.0
# 1 2020-01-01 00:10:00-05:00         College St / Huron St          7163.0
# 2 2020-01-01 00:13:00-05:00  Parliament St / Aberdeen Ave          7108.0
# 3 2020-01-01 00:17:00-05:00       King St E / Victoria St          7311.0
# 4 2020-01-01 00:19:00-05:00         King St E / Jarvis St          7004.0
#
#                    End Time                 End Station Name  Bike Id  \
# 0 2020-01-01 00:19:00-05:00  Yonge St / Alexander St - SMART     3104
# 1 2020-01-01 00:17:00-05:00               Yonge St / Wood St     2126
# 2 2020-01-01 00:22:00-05:00           Front St E / Cherry St     4425
# 3 2020-01-01 00:38:00-05:00      Sherbourne St / Isabella St     4233
# 4 2020-01-01 00:34:00-05:00          University Ave / Elm St     2341
#
#        User Type
# 0  Annual Member
# 1  Annual Member
# 2  Annual Member
# 3  Annual Member
# 4  Casual Member

# %% [markdown]
# Before investgating those missing values, lets drop those rows which duration is shorter than 60s and use statistics to eliminate outliers.

# %%
trips_data_2020 = outliers_eliminate(trips_data_2020)

# %%
trips_data_2020.isnull().sum()
# Out:
# Trip Id                 0
# Subscription Id         0
# Trip Duration           0
# Start Station Id        0
# Start Time              0
# Start Station Name    158
# End Station Id        387
# End Time                0
# End Station Name      523
# Bike Id                 0
# User Type               0
# dtype: int64

# %% [markdown]
# Again, it is appropriate to drop those rows with missing values since it would only cause around 1% of information loss.

# %%
# Use 3 filter to remove those rows with missing values
filter_1  = trips_data_2020["End Station Id"].isnull()==False
filter_2  = trips_data_2020["End Station Name"].isnull()==False
filter_3  = trips_data_2020["Start Station Name"].isnull()==False
trips_data_2020 = trips_data_2020[filter_1 & filter_2&filter_3]

# %% [markdown]
# ## 2017 Data
# Since there are some difference among the 2017, 2018, 2019 and 2020 data in terms of the order of columns and columns' names.
# Furthermore, 2017 and 2018 datesets have 2 missing columns comparing to 2019 and 2020 dataset.
# In this case, some modifications need to be appiled to the 2017 and 2018 dataset
#
# Task to be done:
# - load all the 2017 bike share csv files and combine them in a DataFrame
# - modify the order of columns
# - modify time columns and change the time zone to EST
# - check the missing values

# %%
# Obtain the columns template
col_template = trips_data_2019.columns

# %%
# Obtain the order of columns
col_order = ['trip_id', 'Subscription Id','trip_duration_seconds', 'from_station_id', 'trip_start_time', 
             'from_station_name', 'to_station_id','trip_stop_time', 'to_station_name', 'Bike Id', 'user_type']

# %%
################# TASK 1 ##############################
# Import 2017 dataset
trips_filenames_2017 = [filename for filename in os.listdir() if 'bike_share_2017' in filename]
dfs = []
for i in trips_filenames_2017:
    data =  pd.read_csv(i)
    dfs.append(data)
trips_data_2017 = pd.concat(dfs,axis=0,ignore_index=True)

################# TASK 2 ##############################
# Add the 2 columns that are missing in 2017 and 2018
trips_data_2017.insert(loc=1,column='Subscription Id',value=np.nan)
trips_data_2017.insert(loc=9,column='Bike Id',value=np.nan)

# Organize the order of columns
trips_data_finalized_2017 = trips_data_2017[col_order]

# Rename the columns in order to match the template
trips_data_finalized_2017.columns = col_template

# %%
################# TASK 3 ##############################
# localize and convert time zone
# Drop the UTC in the bracket
est_list = []
for i in pd.DatetimeIndex(pd.to_datetime(trips_data_finalized_2017['Start Time'].map(lambda x: str(x)[:-6]),dayfirst=True)):
    est_list.append(i.tz_localize("UTC").tz_convert("EST"))
trips_data_finalized_2017["Start Time"] = est_list
est_list = []
for i in pd.DatetimeIndex(pd.to_datetime(trips_data_finalized_2017['End Time'].map(lambda x: str(x)[:-6]),dayfirst=True)):
    est_list.append(i.tz_localize("UTC").tz_convert("EST"))
trips_data_finalized_2017["End Time"] = est_list

# %%
trips_data_finalized_2017.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0   712441              NaN            274            7006.0
# 1   712442              NaN            538            7046.0
# 2   712443              NaN            992            7048.0
# 3   712444              NaN           1005            7177.0
# 4   712445              NaN            645            7203.0
#
#                  Start Time                         Start Station Name  \
# 0 2017-01-01 00:03:00-05:00            Bay St / College St (East Side)
# 1 2017-01-01 00:03:00-05:00                 Niagara St / Richmond St W
# 2 2017-01-01 00:05:00-05:00  Front St / Yonge St (Hockey Hall of Fame)
# 3 2017-01-01 00:09:00-05:00            East Liberty St / Pirandello St
# 4 2017-01-01 00:14:00-05:00                Bathurst St / Queens Quay W
#
#    End Station Id                  End Time                  End Station Name  \
# 0          7021.0 2017-01-01 00:08:00-05:00                Bay St / Albert St
# 1          7147.0 2017-01-01 00:12:00-05:00            King St W / Fraser Ave
# 2          7089.0 2017-01-01 00:22:00-05:00              Church St  / Wood St
# 3          7202.0 2017-01-01 00:26:00-05:00  Queen St W / York St (City Hall)
# 4          7010.0 2017-01-01 00:25:00-05:00           King St W / Spadina Ave
#
#    Bike Id User Type
# 0      NaN    Member
# 1      NaN    Member
# 2      NaN    Member
# 3      NaN    Member
# 4      NaN    Member

# %%
trips_data_finalized_2017.isnull().sum()
# Out:
# Trip Id                     0
# Subscription Id       1492369
# Trip Duration               0
# Start Station Id      1026893
# Start Time                  0
# Start Station Name          0
# End Station Id        1026893
# End Time                    1
# End Station Name            1
# Bike Id               1492369
# User Type                   0
# dtype: int64

# %% [markdown]
# It is obvious that this data point has some error since the duration of this trip is 0 second. For the missing value in End Time, it is appropriate to drop this row.

# %%
# Remove the row without the End Time
trips_data_finalized_2017 = trips_data_finalized_2017[trips_data_finalized_2017['End Time'].isnull()==False]

# %% [markdown]
# Now, it is time to work on the name update process. As mentioned in the project file, there are some name inconsistency issue with the station name column. Therefore, it is important to update those names in order to make future task easier. Before that, lets drop those rows which duration is shorter than 60s and use statistics to eliminate outliers.

# %%
# Eliminate outliers and save the dataset
trips_data_finalized_2017 = outliers_eliminate(trips_data_finalized_2017)

# %%
# Compute the percentage of the dataset we drop
print('{}%'.format(round((1-trips_data_finalized_2017.shape[0]/1492369)*100, 2)))
# Out:
# 7.66%

# %% [markdown]
# So far, we drop nearly 8 percent of our data which are regarded as outliers and error data points. Now, the update process should be conducted.

# %%
# Obtain an updated station name list from station dataset
name_list = stations['Station Name'].unique()

# %%
# Create a function for updating a name
def name_update(old_name,name_list):
    """This function is used to update an old_name with the
    new name in name_list
    """
    result_dict  = {0:'Base Station'}
    if old_name in name_list:
        return old_name
    else:
        for new_name in name_list:
            if fuzz.ratio(new_name,old_name) >= 60:
                result_dict[fuzz.ratio(new_name,old_name)] = str(new_name)
    possible_result = result_dict[max(result_dict.keys())]
    return possible_result


    
# Create a function for replacing the name
def name_replace(old_name):
    """This function is used to replace the old station name
    """
    return stations_old[stations_old['Name'] == old_name]['New Name'].tolist()[0]



# Create a function for replace the missing ID
def ID_replace(new_name):
    """This function is used to replace the missing ID
    """
    if new_name == np.nan:
        return np.nan
    elif new_name == "Base Station":
        return np.nan
    else:
        return stations["Station Id"][stations['Station Name'] == new_name].tolist()[0]

# %%
###### First lets check how many names need to be updated ######
updated_index = trips_data_finalized_2017[trips_data_finalized_2017['Start Station Name'].apply(lambda row: row not in name_list)].index
print(len(updated_index))
# Out:
# 340054

# %% [markdown]
# There are 340054 rows which need to update the start station name.
# To increase the efficiency, the first step is to extract the unique station name in both starting and ending points.

# %%
# Extracting both starting names and ending names
stations_start = trips_data_finalized_2017[['Start Station Id', 'Start Station Name']]
stations_end = trips_data_finalized_2017[['End Station Id', 'End Station Name']]
stations_start.columns = stations_end.columns = ['Station Id', 'Name']

# Combine them in to a single dataframe
stations_old = pd.concat([stations_start, stations_end]).dropna(how='all').drop_duplicates().reset_index(drop=True)
stations_old = stations_old.drop_duplicates(subset="Name")

# %% [markdown]
# Update the names in the Station Old DataFrame and save them into a new column called "New name".

# %%
# Update the names
stations_old['New Name'] = stations_old['Name'].apply(lambda row: name_update(row,name_list))

# %%
# View the dataframe
stations_old.head()
# Out:
#    Station Id                                       Name  \
# 0      7006.0            Bay St / College St (East Side)
# 1      7046.0                 Niagara St / Richmond St W
# 2      7048.0  Front St / Yonge St (Hockey Hall of Fame)
# 3      7177.0            East Liberty St / Pirandello St
# 4      7203.0                Bathurst St / Queens Quay W
#
#                                       New Name
# 0              Bay St / College St (East Side)
# 1                   Niagara St / Richmond St W
# 2  Front St W / Yonge St (Hockey Hall of Fame)
# 3              East Liberty St / Pirandello St
# 4                      York St / Queens Quay W

# %% [markdown]
# Based on this DataFrame, we can use this as a translator to update every single name in our original dataset.

# %%
# Updating the start station old name
trips_data_finalized_2017['Start Station Name'] = trips_data_finalized_2017['Start Station Name'].apply(lambda row: name_replace(row))

# %%
# Updating the End station old name
trips_data_finalized_2017['End Station Name'] = trips_data_finalized_2017['End Station Name'].apply(lambda row: name_replace(row))

# %%
# View dataset
trips_data_finalized_2017.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0   712441              NaN            274            7006.0
# 1   712442              NaN            538            7046.0
# 2   712443              NaN            992            7048.0
# 3   712444              NaN           1005            7177.0
# 4   712445              NaN            645            7203.0
#
#                  Start Time                           Start Station Name  \
# 0 2017-01-01 00:03:00-05:00              Bay St / College St (East Side)
# 1 2017-01-01 00:03:00-05:00                   Niagara St / Richmond St W
# 2 2017-01-01 00:05:00-05:00  Front St W / Yonge St (Hockey Hall of Fame)
# 3 2017-01-01 00:09:00-05:00              East Liberty St / Pirandello St
# 4 2017-01-01 00:14:00-05:00                      York St / Queens Quay W
#
#    End Station Id                  End Time                  End Station Name  \
# 0          7021.0 2017-01-01 00:08:00-05:00                Bay St / Albert St
# 1          7147.0 2017-01-01 00:12:00-05:00            King St W / Fraser Ave
# 2          7089.0 2017-01-01 00:22:00-05:00              Church St  / Wood St
# 3          7202.0 2017-01-01 00:26:00-05:00  Queen St W / York St (City Hall)
# 4          7010.0 2017-01-01 00:25:00-05:00           King St W / Spadina Ave
#
#    Bike Id User Type
# 0      NaN    Member
# 1      NaN    Member
# 2      NaN    Member
# 3      NaN    Member
# 4      NaN    Member

# %% [markdown]
# In the third row, the start station name used to be 'Front St / Yonge St (Hockey Hall of Fame)' right now is 'Front St W / Yonge St (Hockey Hall of Fame)', therefore our updating process is working. Next, filling those rows with missing ID.

# %%
# Updating IDs
trips_data_finalized_2017['Start Station Id'] = trips_data_finalized_2017['Start Station Name'].apply(lambda row: ID_replace(row))
trips_data_finalized_2017['End Station Id'] = trips_data_finalized_2017['End Station Name'].apply(lambda row: ID_replace(row))

# %% [markdown]
# Lastly, drop those rows without Starting and End station names and IDs

# %%
# Drop any rows without any station name or ID
mask1 = trips_data_finalized_2017['Start Station Id'].isnull()==False
mask2 = trips_data_finalized_2017['End Station Id'].isnull()==False
trips_data_finalized_2017 = trips_data_finalized_2017[mask1 & mask2]

# %% [markdown]
# ## 2018 Data
# Since there are some difference among the 2017, 2018, 2019 and 2020 data in terms of the order of columns and columns' names.
# Furthermore, 2017 and 2018 datesets have 2 missing columns comparing to 2019 and 2020 dataset.
# In this case, some modifications need to be appiled to the 2017 and 2018 dataset
#
# Task to be done:
# - load all the 2018 bike share csv files and combine them in a DataFrame
# - modify the order of columns
# - modify time columns and change the time zone to EST
# - check the missing values

# %%
# 2018
################# TASK 1 ##############################
trips_filenames_2018 = [filename for filename in os.listdir() if 'bike_share_2018' in filename]
dfs = []
for i in trips_filenames_2018:
    data =  pd.read_csv(i)
    dfs.append(data)
trips_data_2018 = pd.concat(dfs,axis=0,ignore_index=True)

################# TASK 2 ##############################
# Add 2 missing columns
trips_data_2018.insert(loc=1,column='Subscription Id',value=np.nan)
trips_data_2018.insert(loc=9,column='Bike Id',value=np.nan)

# Modify columns
trips_data_finalized_2018 = trips_data_2018[col_order]
trips_data_finalized_2018.columns = col_template

# %%
################# TASK 3 ##############################
# localize and convert time zone
# Drop the EST in the bracket
est_list = []
for i in pd.DatetimeIndex(pd.to_datetime(trips_data_finalized_2018['Start Time'].map(lambda x: str(x)[:-6]),dayfirst=True)):
    est_list.append(i.tz_localize("UTC").tz_convert("EST"))
trips_data_finalized_2018["Start Time"] = est_list
est_list = []
for i in pd.DatetimeIndex(pd.to_datetime(trips_data_finalized_2018['End Time'].map(lambda x: str(x)[:-6]),dayfirst=True)):
    est_list.append(i.tz_localize("UTC").tz_convert("EST"))
trips_data_finalized_2018["End Time"] = est_list

# %%
# View the dataset
trips_data_finalized_2018.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0  2383648              NaN            393              7018
# 1  2383649              NaN            625              7184
# 2  2383650              NaN            233              7235
# 3  2383651              NaN           1138              7202
# 4  2383652              NaN            703              7004
#
#                  Start Time                       Start Station Name  \
# 0 2018-01-01 00:47:00-05:00                   Bremner Blvd / Rees St
# 1 2018-01-01 00:52:00-05:00               Ossington Ave / College St
# 2 2018-01-01 00:55:00-05:00  Bay St / College St (West Side) - SMART
# 3 2018-01-01 00:57:00-05:00         Queen St W / York St (City Hall)
# 4 2018-01-01 01:00:00-05:00                  University Ave / Elm St
#
#    End Station Id                  End Time              End Station Name  \
# 0            7176 2018-01-01 00:54:00-05:00  Bathurst St / Fort York Blvd
# 1            7191 2018-01-01 01:03:00-05:00    Central Tech  (Harbord St)
# 2            7021 2018-01-01 00:59:00-05:00            Bay St / Albert St
# 3            7020 2018-01-01 01:16:00-05:00       Phoebe St / Spadina Ave
# 4            7060 2018-01-01 01:12:00-05:00   Princess St / Adelaide St E
#
#    Bike Id      User Type
# 0      NaN  Annual Member
# 1      NaN  Annual Member
# 2      NaN  Annual Member
# 3      NaN  Annual Member
# 4      NaN  Annual Member

# %% [markdown]
# Before investgating those missing values, lets drop those rows which duration is shorter than 60s and use statistics to eliminate outliers.

# %%
# Eliminate outliers
trips_data_finalized_2018 = outliers_eliminate(trips_data_finalized_2018)

# %%
trips_data_finalized_2018.isnull().sum()
# Out:
# Trip Id                     0
# Subscription Id       1826363
# Trip Duration               0
# Start Station Id            0
# Start Time                  0
# Start Station Name          0
# End Station Id              0
# End Time                    0
# End Station Name            0
# Bike Id               1826363
# User Type                   0
# dtype: int64

# %% [markdown]
# Comparing to other dataset, 2018 bike share does not have any missing values in ID and Names columns. So far, four years' dataset are prepared.

# %%
# Combining four years' data together
finalized_bike_data = pd.concat([trips_data_finalized_2017,trips_data_finalized_2018,trips_data_2019,trips_data_2020],axis=0,ignore_index=True)

# %%
# Final check on missing values in different columns
finalized_bike_data .isnull().sum()
# Out:
# Trip Id                     0
# Subscription Id       3183621
# Trip Duration               0
# Start Station Id            0
# Start Time                  0
# Start Station Name          0
# End Station Id              0
# End Time                    0
# End Station Name            0
# Bike Id               3183621
# User Type                   0
# dtype: int64

# %%
# View the final dataset
finalized_bike_data.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0   712441              NaN            274            7006.0
# 1   712442              NaN            538            7046.0
# 2   712443              NaN            992            7048.0
# 3   712444              NaN           1005            7177.0
# 4   712445              NaN            645            7076.0
#
#                  Start Time                           Start Station Name  \
# 0 2017-01-01 00:03:00-05:00              Bay St / College St (East Side)
# 1 2017-01-01 00:03:00-05:00                   Niagara St / Richmond St W
# 2 2017-01-01 00:05:00-05:00  Front St W / Yonge St (Hockey Hall of Fame)
# 3 2017-01-01 00:09:00-05:00              East Liberty St / Pirandello St
# 4 2017-01-01 00:14:00-05:00                      York St / Queens Quay W
#
#    End Station Id                  End Time                  End Station Name  \
# 0          7021.0 2017-01-01 00:08:00-05:00                Bay St / Albert St
# 1          7147.0 2017-01-01 00:12:00-05:00            King St W / Fraser Ave
# 2          7089.0 2017-01-01 00:22:00-05:00              Church St  / Wood St
# 3          7202.0 2017-01-01 00:26:00-05:00  Queen St W / York St (City Hall)
# 4          7010.0 2017-01-01 00:25:00-05:00           King St W / Spadina Ave
#
#    Bike Id User Type
# 0      NaN    Member
# 1      NaN    Member
# 2      NaN    Member
# 3      NaN    Member
# 4      NaN    Member

# %% [markdown]
# # 3. Weather Data

# %% [markdown]
# ## Step 1: Load weather data

# %%
# Get the file names for the weather files and load them into the notebook as one dataframe
weather_filenames = [filename for filename in os.listdir() if '6158359' in filename]
weather_data = pd.concat(map(pd.read_csv, weather_filenames))
weather_data.head()
# Out:
#    Longitude (x)  Latitude (y)         Station Name  Climate ID  \
# 0          -79.4         43.63  TORONTO CITY CENTRE     6158359
# 1          -79.4         43.63  TORONTO CITY CENTRE     6158359
# 2          -79.4         43.63  TORONTO CITY CENTRE     6158359
# 3          -79.4         43.63  TORONTO CITY CENTRE     6158359
# 4          -79.4         43.63  TORONTO CITY CENTRE     6158359
#
#           Date/Time  Year  Month  Day   Time  Temp (°C)  ... Wind Spd Flag  \
# 0  2017-01-01 00:00  2017      1    1  00:00        1.5  ...           NaN
# 1  2017-01-01 01:00  2017      1    1  01:00        1.5  ...           NaN
# 2  2017-01-01 02:00  2017      1    1  02:00        1.0  ...           NaN
# 3  2017-01-01 03:00  2017      1    1  03:00        1.2  ...           NaN
# 4  2017-01-01 04:00  2017      1    1  04:00        1.3  ...           NaN
#
#    Visibility (km) Visibility Flag  Stn Press (kPa) Stn Press Flag  Hmdx  \
# 0             16.1             NaN            99.81            NaN   NaN
# 1             16.1             NaN           100.01            NaN   NaN
# 2             16.1             NaN           100.14            NaN   NaN
# 3             16.1             NaN           100.32            NaN   NaN
# 4             16.1             NaN           100.48            NaN   NaN
#
#   Hmdx Flag  Wind Chill Wind Chill Flag  Weather
# 0       NaN         NaN             NaN      NaN
# 1       NaN         NaN             NaN      NaN
# 2       NaN         NaN             NaN      NaN
# 3       NaN         NaN             NaN      NaN
# 4       NaN         NaN             NaN      NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Step 2: Clean weather data

# %%
# Localize the date and time and set as the index as well as removing the column afterwards
weather_data.index = pd.DatetimeIndex(weather_data['Date/Time'])
weather_data.drop('Date/Time', axis = 1, inplace = True)
weather_data.index = weather_data.index.tz_localize('EST')
weather_data.head()
# Out:
#                            Longitude (x)  Latitude (y)         Station Name  \
# Date/Time
# 2017-01-01 00:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
# 2017-01-01 01:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
# 2017-01-01 02:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
# 2017-01-01 03:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
# 2017-01-01 04:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
#
#                            Climate ID  Year  Month  Day   Time  Temp (°C)  \
# Date/Time
# 2017-01-01 00:00:00-05:00     6158359  2017      1    1  00:00        1.5
# 2017-01-01 01:00:00-05:00     6158359  2017      1    1  01:00        1.5
# 2017-01-01 02:00:00-05:00     6158359  2017      1    1  02:00        1.0
# 2017-01-01 03:00:00-05:00     6158359  2017      1    1  03:00        1.2
# 2017-01-01 04:00:00-05:00     6158359  2017      1    1  04:00        1.3
#
#                           Temp Flag  ...  Wind Spd Flag Visibility (km)  \
# Date/Time                            ...
# 2017-01-01 00:00:00-05:00       NaN  ...            NaN            16.1
# 2017-01-01 01:00:00-05:00       NaN  ...            NaN            16.1
# 2017-01-01 02:00:00-05:00       NaN  ...            NaN            16.1
# 2017-01-01 03:00:00-05:00       NaN  ...            NaN            16.1
# 2017-01-01 04:00:00-05:00       NaN  ...            NaN            16.1
#
#                            Visibility Flag Stn Press (kPa)  Stn Press Flag  \
# Date/Time
# 2017-01-01 00:00:00-05:00              NaN           99.81             NaN
# 2017-01-01 01:00:00-05:00              NaN          100.01             NaN
# 2017-01-01 02:00:00-05:00              NaN          100.14             NaN
# 2017-01-01 03:00:00-05:00              NaN          100.32             NaN
# 2017-01-01 04:00:00-05:00              NaN          100.48             NaN
#
#                           Hmdx  Hmdx Flag Wind Chill  Wind Chill Flag Weather
# Date/Time
# 2017-01-01 00:00:00-05:00  NaN        NaN        NaN              NaN     NaN
# 2017-01-01 01:00:00-05:00  NaN        NaN        NaN              NaN     NaN
# 2017-01-01 02:00:00-05:00  NaN        NaN        NaN              NaN     NaN
# 2017-01-01 03:00:00-05:00  NaN        NaN        NaN              NaN     NaN
# 2017-01-01 04:00:00-05:00  NaN        NaN        NaN              NaN     NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Keep important columns only

# %% [markdown]
# Some columns contain redundant or not useful information. For example, the 'Climate ID' column contains the number assigned to the weather station, but all of the weather data come from the same station; therefore, this column is redundant and should be removed.
#
# To determine what to keep and what to discard, first the non-numerical data type columns are investigated followed by the numerical data type columns.

# %%
# Create a dataframe containing non-numerical data type columns to investigate
non_num = weather_data.select_dtypes(exclude = 'number')
display(non_num.head())

# Check the unique values of each column
print(non_num.apply(lambda  col: col.unique()))
# Out:
#                                   Station Name   Time Temp Flag  \
# Date/Time
# 2017-01-01 00:00:00-05:00  TORONTO CITY CENTRE  00:00       NaN
# 2017-01-01 01:00:00-05:00  TORONTO CITY CENTRE  01:00       NaN
# 2017-01-01 02:00:00-05:00  TORONTO CITY CENTRE  02:00       NaN
# 2017-01-01 03:00:00-05:00  TORONTO CITY CENTRE  03:00       NaN
# 2017-01-01 04:00:00-05:00  TORONTO CITY CENTRE  04:00       NaN
#
#                           Dew Point Temp Flag Rel Hum Flag Wind Dir Flag  \
# Date/Time
# 2017-01-01 00:00:00-05:00                 NaN          NaN           NaN
# 2017-01-01 01:00:00-05:00                 NaN          NaN           NaN
# 2017-01-01 02:00:00-05:00                 NaN          NaN           NaN
# 2017-01-01 03:00:00-05:00                 NaN          NaN           NaN
# 2017-01-01 04:00:00-05:00                 NaN          NaN           NaN
#
#                           Wind Spd Flag Visibility Flag Stn Press Flag Weather
# Date/Time
# 2017-01-01 00:00:00-05:00           NaN             NaN            NaN     NaN
# 2017-01-01 01:00:00-05:00           NaN             NaN            NaN     NaN
# 2017-01-01 02:00:00-05:00           NaN             NaN            NaN     NaN
# 2017-01-01 03:00:00-05:00           NaN             NaN            NaN     NaN
# 2017-01-01 04:00:00-05:00           NaN             NaN            NaN     NaN
# Station Name                                       [TORONTO CITY CENTRE]
# Time                   [00:00, 01:00, 02:00, 03:00, 04:00, 05:00, 06:...
# Temp Flag                                                       [nan, M]
# Dew Point Temp Flag                                             [nan, M]
# Rel Hum Flag                                                    [nan, M]
# Wind Dir Flag                                                   [nan, M]
# Wind Spd Flag                                                   [nan, M]
# Visibility Flag                                                 [nan, M]
# Stn Press Flag                                                  [nan, M]
# Weather                [nan, Fog, Rain,Fog, Rain, Snow, Moderate Rain...
# dtype: object

# %% [markdown]
# The 'Time' column corresponds to the hour of observation, which is already included in the 'Date/Time' index. The 'Weather' column is the visual observation of the weather environment and appears to be important. The 'Station Name' column shows the name of the weather station which is redundant since the weather data were all taken from the same station. There are a number of columns containing the word 'Flag', and only contains NaN or 'M' values. According to Environment and Climate Change Canada, the 'M' represents 'missing' which means the data is unretrievable or unavailable (https://climate.weather.gc.ca/FAQ_e.html#Q4). Additionally, it appears that there are some 'Flag' columns that were not included, so those should be investigated as well.

# %%
# Look at the number of NaN values in the columns containing the word 'Flag'
flag_columns = [col for col in weather_data.columns if 'Flag' in col]
weather_data[flag_columns].isnull().sum(axis=0).to_frame('count')
# Out:
#                      count
# Temp Flag            34975
# Dew Point Temp Flag  34925
# Rel Hum Flag         34933
# Wind Dir Flag        34010
# Wind Spd Flag        35049
# Visibility Flag      35042
# Stn Press Flag       34971
# Hmdx Flag            35064
# Wind Chill Flag      35064

# %% [markdown]
# These other columns should be removed as well. Overall, based on the investigation, the only column that should be kept is the 'Weather' column.

# %%
# Drop the non-useful columns
clean_weather_data = weather_data.drop(set(flag_columns + list(non_num.columns.drop('Weather'))), axis = 1)
display(clean_weather_data.head())
print(clean_weather_data.nunique())
# Out:
#                            Longitude (x)  Latitude (y)  Climate ID  Year  \
# Date/Time
# 2017-01-01 00:00:00-05:00          -79.4         43.63     6158359  2017
# 2017-01-01 01:00:00-05:00          -79.4         43.63     6158359  2017
# 2017-01-01 02:00:00-05:00          -79.4         43.63     6158359  2017
# 2017-01-01 03:00:00-05:00          -79.4         43.63     6158359  2017
# 2017-01-01 04:00:00-05:00          -79.4         43.63     6158359  2017
#
#                            Month  Day  Temp (°C)  Dew Point Temp (°C)  \
# Date/Time
# 2017-01-01 00:00:00-05:00      1    1        1.5                 -3.6
# 2017-01-01 01:00:00-05:00      1    1        1.5                 -3.9
# 2017-01-01 02:00:00-05:00      1    1        1.0                 -4.3
# 2017-01-01 03:00:00-05:00      1    1        1.2                 -4.3
# 2017-01-01 04:00:00-05:00      1    1        1.3                 -4.4
#
#                            Rel Hum (%)  Wind Dir (10s deg)  Wind Spd (km/h)  \
# Date/Time
# 2017-01-01 00:00:00-05:00         69.0                26.0             39.0
# 2017-01-01 01:00:00-05:00         67.0                27.0             35.0
# 2017-01-01 02:00:00-05:00         68.0                26.0             32.0
# 2017-01-01 03:00:00-05:00         67.0                26.0             37.0
# 2017-01-01 04:00:00-05:00         66.0                26.0             28.0
#
#                            Visibility (km)  Stn Press (kPa)  Hmdx  Wind Chill  \
# Date/Time
# 2017-01-01 00:00:00-05:00             16.1            99.81   NaN         NaN
# 2017-01-01 01:00:00-05:00             16.1           100.01   NaN         NaN
# 2017-01-01 02:00:00-05:00             16.1           100.14   NaN         NaN
# 2017-01-01 03:00:00-05:00             16.1           100.32   NaN         NaN
# 2017-01-01 04:00:00-05:00             16.1           100.48   NaN         NaN
#
#                           Weather
# Date/Time
# 2017-01-01 00:00:00-05:00     NaN
# 2017-01-01 01:00:00-05:00     NaN
# 2017-01-01 02:00:00-05:00     NaN
# 2017-01-01 03:00:00-05:00     NaN
# 2017-01-01 04:00:00-05:00     NaN
# Longitude (x)            1
# Latitude (y)             1
# Climate ID               1
# Year                     4
# Month                   12
# Day                     31
# Temp (°C)              526
# Dew Point Temp (°C)    520
# Rel Hum (%)             84
# Wind Dir (10s deg)      36
# Wind Spd (km/h)         40
# Visibility (km)         22
# Stn Press (kPa)        553
# Hmdx                    19
# Wind Chill              36
# Weather                 24
# dtype: int64

# %% [markdown]
# With the number of columns greatly reduced, the rest can be individually selected. The 'Year', 'Month', 'Day', and 'Climate ID' columns can be removed. The 'Longitude (x)' and 'Latitude (y)' could also be removed since the coordinates of the weather station remain the same. Additionally, 'Stn Press (kPa)' is not important because small atmospheric pressure changes have infinitesimal effects on everyday activities. Given the small elevation difference across Toronto, pressure due to elevation change is insignificant.

# %%
# Check the statistics description of atmospheric pressure
clean_weather_data['Stn Press (kPa)'].describe()
# Out:
# count    34602.000000
# mean       100.708158
# std          0.799043
# min         97.730000
# 25%        100.200000
# 50%        100.690000
# 75%        101.220000
# max        103.710000
# Name: Stn Press (kPa), dtype: float64

# %% [markdown]
# As expected, the atmospheric pressure ranges from 97.73 kPa to 103.71 kPa, which is not a great difference and can be removed.

# %%
# Drop the rest of the non-useful columns
clean_weather_data.drop(['Year', 'Month', 'Day', 'Climate ID', 'Longitude (x)', 'Latitude (y)', 'Stn Press (kPa)'], 
                        axis = 1, inplace = True)
clean_weather_data.head()
# Out:
#                            Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# Date/Time
# 2017-01-01 00:00:00-05:00        1.5                 -3.6         69.0
# 2017-01-01 01:00:00-05:00        1.5                 -3.9         67.0
# 2017-01-01 02:00:00-05:00        1.0                 -4.3         68.0
# 2017-01-01 03:00:00-05:00        1.2                 -4.3         67.0
# 2017-01-01 04:00:00-05:00        1.3                 -4.4         66.0
#
#                            Wind Dir (10s deg)  Wind Spd (km/h)  \
# Date/Time
# 2017-01-01 00:00:00-05:00                26.0             39.0
# 2017-01-01 01:00:00-05:00                27.0             35.0
# 2017-01-01 02:00:00-05:00                26.0             32.0
# 2017-01-01 03:00:00-05:00                26.0             37.0
# 2017-01-01 04:00:00-05:00                26.0             28.0
#
#                            Visibility (km)  Hmdx  Wind Chill Weather
# Date/Time
# 2017-01-01 00:00:00-05:00             16.1   NaN         NaN     NaN
# 2017-01-01 01:00:00-05:00             16.1   NaN         NaN     NaN
# 2017-01-01 02:00:00-05:00             16.1   NaN         NaN     NaN
# 2017-01-01 03:00:00-05:00             16.1   NaN         NaN     NaN
# 2017-01-01 04:00:00-05:00             16.1   NaN         NaN     NaN

# %% [markdown]
# ### Treating missing data

# %% [markdown]
# Now that the redundant and non-useful columns are removed, the final step is to determine what to do with missing values.

# %% [markdown]
# #### Locate missing values

# %%
# Check missing values
display(clean_weather_data.isnull().sum(axis=0).to_frame('count'))
display(clean_weather_data.resample('Y').agg(lambda row: row.isnull().sum()))
# Out:
#                      count
# Temp (°C)              459
# Dew Point Temp (°C)    508
# Rel Hum (%)            500
# Wind Dir (10s deg)    2385
# Wind Spd (km/h)        384
# Visibility (km)        391
# Hmdx                 29397
# Wind Chill           28998
# Weather              29547
#                            Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# Date/Time
# 2017-12-31 00:00:00-05:00       11.0                 11.0         10.0
# 2018-12-31 00:00:00-05:00        4.0                  4.0          2.0
# 2019-12-31 00:00:00-05:00       95.0                145.0        145.0
# 2020-12-31 00:00:00-05:00      349.0                348.0        343.0
#
#                            Wind Dir (10s deg)  Wind Spd (km/h)  \
# Date/Time
# 2017-12-31 00:00:00-05:00               530.0              9.0
# 2018-12-31 00:00:00-05:00               504.0              2.0
# 2019-12-31 00:00:00-05:00               595.0             23.0
# 2020-12-31 00:00:00-05:00               756.0            350.0
#
#                            Visibility (km)    Hmdx  Wind Chill  Weather
# Date/Time
# 2017-12-31 00:00:00-05:00             11.0  7599.0      7251.0     7390
# 2018-12-31 00:00:00-05:00              4.0  6979.0      7084.0     7336
# 2019-12-31 00:00:00-05:00             24.0  7608.0      6936.0     7213
# 2020-12-31 00:00:00-05:00            352.0  7211.0      7727.0     7608

# %% [markdown]
# There appears to be a lot of missing data in 2019 and 2020 compared to the other years, particularly the latter. Also, 'Hmdx', 'Wind Chill', and 'Weather columns have significantly more missing values than the other columns.

# %%
# Check monthly weather data in 2019 and 2020 for missing values
display(clean_weather_data.loc['2019'].resample('M').agg(lambda row: row.isnull().sum()))
display(clean_weather_data.loc['2020'].resample('M').agg(lambda row: row.isnull().sum()))
# Out:
#                            Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# Date/Time
# 2019-01-31 00:00:00-05:00        0.0                  0.0          0.0
# 2019-02-28 00:00:00-05:00        0.0                  0.0          0.0
# 2019-03-31 00:00:00-05:00        1.0                  1.0          1.0
# 2019-04-30 00:00:00-05:00        0.0                  0.0          0.0
# 2019-05-31 00:00:00-05:00       28.0                 28.0         28.0
# 2019-06-30 00:00:00-05:00       59.0                109.0        109.0
# 2019-07-31 00:00:00-05:00        7.0                  7.0          7.0
# 2019-08-31 00:00:00-05:00        0.0                  0.0          0.0
# 2019-09-30 00:00:00-05:00        0.0                  0.0          0.0
# 2019-10-31 00:00:00-05:00        0.0                  0.0          0.0
# 2019-11-30 00:00:00-05:00        0.0                  0.0          0.0
# 2019-12-31 00:00:00-05:00        0.0                  0.0          0.0
#
#                            Wind Dir (10s deg)  Wind Spd (km/h)  \
# Date/Time
# 2019-01-31 00:00:00-05:00                21.0              0.0
# 2019-02-28 00:00:00-05:00                24.0              0.0
# 2019-03-31 00:00:00-05:00                33.0              3.0
# 2019-04-30 00:00:00-05:00                43.0              0.0
# 2019-05-31 00:00:00-05:00                88.0             12.0
# 2019-06-30 00:00:00-05:00                74.0              1.0
# 2019-07-31 00:00:00-05:00               103.0              7.0
# 2019-08-31 00:00:00-05:00                75.0              0.0
# 2019-09-30 00:00:00-05:00                49.0              0.0
# 2019-10-31 00:00:00-05:00                32.0              0.0
# 2019-11-30 00:00:00-05:00                25.0              0.0
# 2019-12-31 00:00:00-05:00                28.0              0.0
#
#                            Visibility (km)   Hmdx  Wind Chill  Weather
# Date/Time
# 2019-01-31 00:00:00-05:00              0.0  744.0       197.0      522
# 2019-02-28 00:00:00-05:00              0.0  672.0       202.0      455
# 2019-03-31 00:00:00-05:00              4.0  744.0       417.0      633
# 2019-04-30 00:00:00-05:00              0.0  720.0       707.0      568
# 2019-05-31 00:00:00-05:00             12.0  741.0       744.0      570
# 2019-06-30 00:00:00-05:00              1.0  624.0       720.0      629
# 2019-07-31 00:00:00-05:00              7.0  233.0       744.0      671
# 2019-08-31 00:00:00-05:00              0.0  334.0       744.0      690
# 2019-09-30 00:00:00-05:00              0.0  598.0       720.0      667
# 2019-10-31 00:00:00-05:00              0.0  734.0       744.0      633
# 2019-11-30 00:00:00-05:00              0.0  720.0       529.0      594
# 2019-12-31 00:00:00-05:00              0.0  744.0       468.0      581
#                            Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# Date/Time
# 2020-01-31 00:00:00-05:00        5.0                  5.0          0.0
# 2020-02-29 00:00:00-05:00        0.0                  0.0          0.0
# 2020-03-31 00:00:00-05:00        0.0                  0.0          0.0
# 2020-04-30 00:00:00-05:00        0.0                  0.0          0.0
# 2020-05-31 00:00:00-05:00        0.0                  0.0          0.0
# 2020-06-30 00:00:00-05:00        7.0                  6.0          6.0
# 2020-07-31 00:00:00-05:00        0.0                  0.0          0.0
# 2020-08-31 00:00:00-05:00        0.0                  0.0          0.0
# 2020-09-30 00:00:00-05:00        0.0                  0.0          0.0
# 2020-10-31 00:00:00-05:00        0.0                  0.0          0.0
# 2020-11-30 00:00:00-05:00        1.0                  1.0          1.0
# 2020-12-31 00:00:00-05:00      336.0                336.0        336.0
#
#                            Wind Dir (10s deg)  Wind Spd (km/h)  \
# Date/Time
# 2020-01-31 00:00:00-05:00                25.0              5.0
# 2020-02-29 00:00:00-05:00                 9.0              0.0
# 2020-03-31 00:00:00-05:00                27.0              2.0
# 2020-04-30 00:00:00-05:00                31.0              0.0
# 2020-05-31 00:00:00-05:00                43.0              0.0
# 2020-06-30 00:00:00-05:00                64.0              6.0
# 2020-07-31 00:00:00-05:00                43.0              0.0
# 2020-08-31 00:00:00-05:00                58.0              0.0
# 2020-09-30 00:00:00-05:00                49.0              0.0
# 2020-10-31 00:00:00-05:00                30.0              0.0
# 2020-11-30 00:00:00-05:00                38.0              1.0
# 2020-12-31 00:00:00-05:00               339.0            336.0
#
#                            Visibility (km)   Hmdx  Wind Chill  Weather
# Date/Time
# 2020-01-31 00:00:00-05:00              3.0  744.0       429.0      590
# 2020-02-29 00:00:00-05:00              0.0  696.0       293.0      518
# 2020-03-31 00:00:00-05:00              0.0  744.0       643.0      613
# 2020-04-30 00:00:00-05:00              0.0  720.0       694.0      639
# 2020-05-31 00:00:00-05:00              0.0  701.0       734.0      649
# 2020-06-30 00:00:00-05:00              5.0  489.0       720.0      674
# 2020-07-31 00:00:00-05:00              0.0   53.0       744.0      718
# 2020-08-31 00:00:00-05:00              7.0  249.0       744.0      694
# 2020-09-30 00:00:00-05:00              0.0  610.0       720.0      641
# 2020-10-31 00:00:00-05:00              0.0  741.0       733.0      634
# 2020-11-30 00:00:00-05:00              1.0  720.0       688.0      606
# 2020-12-31 00:00:00-05:00            336.0  744.0       585.0      632

# %% [markdown]
# In 2019, there appears to be numerous missing data in May and June, while in 2020 there is a significant loss of data in December.

# %%
# Check daily weather data in December 2020 for missing values
display(clean_weather_data.loc['2020-12'].resample('D').agg(lambda row: row.isnull().sum()))
# Out:
#                            Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# Date/Time
# 2020-12-01 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-02 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-03 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-04 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-05 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-06 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-07 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-08 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-09 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-10 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-11 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-12 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-13 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-14 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-15 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-16 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-17 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-18 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-19 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-20 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-21 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-22 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-23 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-24 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-25 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-26 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-27 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-28 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-29 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-30 00:00:00-05:00       24.0                 24.0         24.0
# 2020-12-31 00:00:00-05:00       24.0                 24.0         24.0
#
#                            Wind Dir (10s deg)  Wind Spd (km/h)  \
# Date/Time
# 2020-12-01 00:00:00-05:00                 0.0              0.0
# 2020-12-02 00:00:00-05:00                 0.0              0.0
# 2020-12-03 00:00:00-05:00                 0.0              0.0
# 2020-12-04 00:00:00-05:00                 0.0              0.0
# 2020-12-05 00:00:00-05:00                 0.0              0.0
# 2020-12-06 00:00:00-05:00                 0.0              0.0
# 2020-12-07 00:00:00-05:00                 0.0              0.0
# 2020-12-08 00:00:00-05:00                 0.0              0.0
# 2020-12-09 00:00:00-05:00                 0.0              0.0
# 2020-12-10 00:00:00-05:00                 0.0              0.0
# 2020-12-11 00:00:00-05:00                 2.0              0.0
# 2020-12-12 00:00:00-05:00                 0.0              0.0
# 2020-12-13 00:00:00-05:00                 0.0              0.0
# 2020-12-14 00:00:00-05:00                 0.0              0.0
# 2020-12-15 00:00:00-05:00                 1.0              0.0
# 2020-12-16 00:00:00-05:00                 0.0              0.0
# 2020-12-17 00:00:00-05:00                 0.0              0.0
# 2020-12-18 00:00:00-05:00                24.0             24.0
# 2020-12-19 00:00:00-05:00                24.0             24.0
# 2020-12-20 00:00:00-05:00                24.0             24.0
# 2020-12-21 00:00:00-05:00                24.0             24.0
# 2020-12-22 00:00:00-05:00                24.0             24.0
# 2020-12-23 00:00:00-05:00                24.0             24.0
# 2020-12-24 00:00:00-05:00                24.0             24.0
# 2020-12-25 00:00:00-05:00                24.0             24.0
# 2020-12-26 00:00:00-05:00                24.0             24.0
# 2020-12-27 00:00:00-05:00                24.0             24.0
# 2020-12-28 00:00:00-05:00                24.0             24.0
# 2020-12-29 00:00:00-05:00                24.0             24.0
# 2020-12-30 00:00:00-05:00                24.0             24.0
# 2020-12-31 00:00:00-05:00                24.0             24.0
#
#                            Visibility (km)  Hmdx  Wind Chill  Weather
# Date/Time
# 2020-12-01 00:00:00-05:00              0.0  24.0         8.0        1
# 2020-12-02 00:00:00-05:00              0.0  24.0        18.0       19
# 2020-12-03 00:00:00-05:00              0.0  24.0        24.0       24
# 2020-12-04 00:00:00-05:00              0.0  24.0        24.0       13
# 2020-12-05 00:00:00-05:00              0.0  24.0        16.0       24
# 2020-12-06 00:00:00-05:00              0.0  24.0         5.0       24
# 2020-12-07 00:00:00-05:00              0.0  24.0         3.0       24
# 2020-12-08 00:00:00-05:00              0.0  24.0        12.0       24
# 2020-12-09 00:00:00-05:00              0.0  24.0        24.0       10
# 2020-12-10 00:00:00-05:00              0.0  24.0        24.0       20
# 2020-12-11 00:00:00-05:00              0.0  24.0        24.0        8
# 2020-12-12 00:00:00-05:00              0.0  24.0        24.0       14
# 2020-12-13 00:00:00-05:00              0.0  24.0        24.0       24
# 2020-12-14 00:00:00-05:00              0.0  24.0        19.0       23
# 2020-12-15 00:00:00-05:00              0.0  24.0         0.0       18
# 2020-12-16 00:00:00-05:00              0.0  24.0         0.0        9
# 2020-12-17 00:00:00-05:00              0.0  24.0         0.0       17
# 2020-12-18 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-19 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-20 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-21 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-22 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-23 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-24 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-25 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-26 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-27 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-28 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-29 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-30 00:00:00-05:00             24.0  24.0        24.0       24
# 2020-12-31 00:00:00-05:00             24.0  24.0        24.0       24

# %% [markdown]
# It seems that from December 18, 2020 onwards, no weather data of any kind is recorded (weather data is reported hourly, so there should be 24 reports per day). Since the 2020 bikeshare data is currently missing November and December 2020 data, the November and December 2020 weather data will not be used; therefore, the missing values are insignificant in this case.

# %% [markdown]
# #### Imputing/filling missing values

# %% [markdown]
# ***Humidex and Wind Chill***

# %%
# Visualizing number of missing values in 'Hmdx' and 'Wind Chill' columns
clean_weather_data.loc['2019'].resample('M').agg(
    lambda row: row.isnull().sum())[['Hmdx', 'Wind Chill']].plot(
    figsize = (10, 6))
plt.title('Number of missing values for humidex and wind chill columns in 2019', fontsize = 18)
plt.xlabel('Month', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.legend(['Hmdx', 'Wind Chill'], fontsize = 14)

clean_weather_data.loc['2020'].resample('M').agg(
    lambda row: row.isnull().sum())[['Hmdx', 'Wind Chill']].plot(
    figsize = (10, 6))
plt.title('Number of missing values for humidex and wind chill columns in 2020', fontsize = 18)
plt.xlabel('Month', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.legend(['Hmdx', 'Wind Chill'], fontsize = 14);

# %% [markdown]
# It appears that there are more missing wind chill values and fewer missing humidex values in the summer and vice versa in the winter. This makes sense as humidex is mainly an indicator of how hot a person would feel, while wind chill indicates how cold a person would feel.
#
# According to Environment and Climate Change Canada (https://climate.weather.gc.ca/glossary_e.html), the humidex values are only reported if (1) air temperature is greater than or equal to 20 degrees celsius and (2) the humidex value is at least 1 degree greater than the air temperature. Similarily, wind chill is only calculated if the air temperature is greater than or equal to 0 degrees celsius. As a result, the missing values in 'Hmdx' and 'Wind Chill' should not be modified.

# %% [markdown]
# ***Weather***

# %% [markdown]
# For the 'Weather' column, the missing values indicate that no weather phenomena were reported (https://climate.weather.gc.ca/FAQ_e.html#Q5). This is assumed to be clear weather, and subsequently any missing values will be replaced with 'Clear'.

# %%
# Modifying missing values in 'Weather' column
clean_weather_data['Weather'].fillna('Clear', inplace = True)
clean_weather_data.head()
# Out:
#                            Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# Date/Time
# 2017-01-01 00:00:00-05:00        1.5                 -3.6         69.0
# 2017-01-01 01:00:00-05:00        1.5                 -3.9         67.0
# 2017-01-01 02:00:00-05:00        1.0                 -4.3         68.0
# 2017-01-01 03:00:00-05:00        1.2                 -4.3         67.0
# 2017-01-01 04:00:00-05:00        1.3                 -4.4         66.0
#
#                            Wind Dir (10s deg)  Wind Spd (km/h)  \
# Date/Time
# 2017-01-01 00:00:00-05:00                26.0             39.0
# 2017-01-01 01:00:00-05:00                27.0             35.0
# 2017-01-01 02:00:00-05:00                26.0             32.0
# 2017-01-01 03:00:00-05:00                26.0             37.0
# 2017-01-01 04:00:00-05:00                26.0             28.0
#
#                            Visibility (km)  Hmdx  Wind Chill Weather
# Date/Time
# 2017-01-01 00:00:00-05:00             16.1   NaN         NaN   Clear
# 2017-01-01 01:00:00-05:00             16.1   NaN         NaN   Clear
# 2017-01-01 02:00:00-05:00             16.1   NaN         NaN   Clear
# 2017-01-01 03:00:00-05:00             16.1   NaN         NaN   Clear
# 2017-01-01 04:00:00-05:00             16.1   NaN         NaN   Clear

# %% [markdown]
# ***The rest of the columns***

# %% [markdown]
# Due to the frequency of weather reports, the change in magnitude should not be significant between each hour (wind direction and wind speed may change slightly more). For example, if the temperature at 10 AM is 10 degrees celsius, then it would be unlikely that the 11 AM temperature suddenly increases to 20 degrees celsius. Therefore, it should be reasonable to impute missing values based on the time-adjacent valid observations. Except for 'Hmdx', 'Wind Chill', and 'Weather' columns, all other columns will have missing values filled using linear interpolation between valid observations.

# %%
# Linear interpolating values 
col_interp = clean_weather_data.columns.drop(['Hmdx', 'Wind Chill', 'Weather'])
clean_weather_data[col_interp] = clean_weather_data[col_interp].interpolate(
    method = 'linear', axis = 0, limit_direction = 'both').round(1)

# %% [markdown]
# Now there should not be any missing values in the data except for 'Hmdx' and 'Wind Chill' columns.

# %%
# Check if there are still missing values
display(clean_weather_data.resample('Y').agg(lambda row: row.isnull().sum()))
# Out:
#                            Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# Date/Time
# 2017-12-31 00:00:00-05:00        0.0                  0.0          0.0
# 2018-12-31 00:00:00-05:00        0.0                  0.0          0.0
# 2019-12-31 00:00:00-05:00        0.0                  0.0          0.0
# 2020-12-31 00:00:00-05:00        0.0                  0.0          0.0
#
#                            Wind Dir (10s deg)  Wind Spd (km/h)  \
# Date/Time
# 2017-12-31 00:00:00-05:00                 0.0              0.0
# 2018-12-31 00:00:00-05:00                 0.0              0.0
# 2019-12-31 00:00:00-05:00                 0.0              0.0
# 2020-12-31 00:00:00-05:00                 0.0              0.0
#
#                            Visibility (km)    Hmdx  Wind Chill  Weather
# Date/Time
# 2017-12-31 00:00:00-05:00              0.0  7599.0      7251.0        0
# 2018-12-31 00:00:00-05:00              0.0  6979.0      7084.0        0
# 2019-12-31 00:00:00-05:00              0.0  7608.0      6936.0        0
# 2020-12-31 00:00:00-05:00              0.0  7211.0      7727.0        0

# %%
# View the data
clean_weather_data.head()
# Out:
#                            Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# Date/Time
# 2017-01-01 00:00:00-05:00        1.5                 -3.6         69.0
# 2017-01-01 01:00:00-05:00        1.5                 -3.9         67.0
# 2017-01-01 02:00:00-05:00        1.0                 -4.3         68.0
# 2017-01-01 03:00:00-05:00        1.2                 -4.3         67.0
# 2017-01-01 04:00:00-05:00        1.3                 -4.4         66.0
#
#                            Wind Dir (10s deg)  Wind Spd (km/h)  \
# Date/Time
# 2017-01-01 00:00:00-05:00                26.0             39.0
# 2017-01-01 01:00:00-05:00                27.0             35.0
# 2017-01-01 02:00:00-05:00                26.0             32.0
# 2017-01-01 03:00:00-05:00                26.0             37.0
# 2017-01-01 04:00:00-05:00                26.0             28.0
#
#                            Visibility (km)  Hmdx  Wind Chill Weather
# Date/Time
# 2017-01-01 00:00:00-05:00             16.1   NaN         NaN   Clear
# 2017-01-01 01:00:00-05:00             16.1   NaN         NaN   Clear
# 2017-01-01 02:00:00-05:00             16.1   NaN         NaN   Clear
# 2017-01-01 03:00:00-05:00             16.1   NaN         NaN   Clear
# 2017-01-01 04:00:00-05:00             16.1   NaN         NaN   Clear

# %% [markdown]
# # 4. Combine the three datasets

# %% [markdown]
# ## Merging Bike Share and Station

# %%
# Modify the station data and columns and extract the useful information
stations_start = stations[["Station Id",'lat','lon','capacity']]
stations_start.columns = ["Start Station Id",'Start_lat','Start_lon','Start_capacity']
stations_end = stations[["Station Id",'lat','lon','capacity']]
stations_end.columns = ["End Station Id",'End_lat','End_lon','End_capacity']

# %%
# Merging with the bike share data
df_1 = finalized_bike_data.merge(stations_start, how='inner', on='Start Station Id')
df_2 = df_1.merge(stations_end, how='inner', on='End Station Id')

# %%
# View the dataset
df_2.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0   712441              NaN            274            7006.0
# 1   717862              NaN            252            7006.0
# 2   719500              NaN            241            7006.0
# 3   722310              NaN            262            7006.0
# 4   723078              NaN            285            7006.0
#
#                  Start Time               Start Station Name  End Station Id  \
# 0 2017-01-01 00:03:00-05:00  Bay St / College St (East Side)          7021.0
# 1 2017-01-05 18:06:00-05:00  Bay St / College St (East Side)          7021.0
# 2 2017-01-06 18:46:00-05:00  Bay St / College St (East Side)          7021.0
# 3 2017-01-09 19:17:00-05:00  Bay St / College St (East Side)          7021.0
# 4 2017-01-10 17:37:00-05:00  Bay St / College St (East Side)          7021.0
#
#                    End Time    End Station Name  Bike Id User Type  Start_lat  \
# 0 2017-01-01 00:08:00-05:00  Bay St / Albert St      NaN    Member  43.660439
# 1 2017-01-05 18:11:00-05:00  Bay St / Albert St      NaN    Member  43.660439
# 2 2017-01-06 18:50:00-05:00  Bay St / Albert St      NaN    Member  43.660439
# 3 2017-01-09 19:21:00-05:00  Bay St / Albert St      NaN    Member  43.660439
# 4 2017-01-10 17:42:00-05:00  Bay St / Albert St      NaN    Member  43.660439
#
#    Start_lon  Start_capacity    End_lat    End_lon  End_capacity
# 0 -79.385525              11  43.653264 -79.382458            35
# 1 -79.385525              11  43.653264 -79.382458            35
# 2 -79.385525              11  43.653264 -79.382458            35
# 3 -79.385525              11  43.653264 -79.382458            35
# 4 -79.385525              11  43.653264 -79.382458            35

# %% [markdown]
# ## Merging Weather Data

# %% [markdown]
# Since the weather data is reported every hour, the time of bike share data should be rounded to the nearest hour.

# %%
# Round the starting time to the nearest hour
df_2['Start Time'] = df_2['Start Time'].apply(lambda row: row.round('60min'))

# %%
# Merging the dataset with weather time on starting time
data_merged = pd.merge(df_2,clean_weather_data,left_on="Start Time",right_index=True,how="inner",sort=False)

# %% [markdown]
# The Subscription Id and Bike Id columns contain missing values in 2017 and 2018, but it would not make sense to impute or fill the missing values. Additionally, these columns do not seem to be important for further data analysis as they are merely identifiers; therefore, they will be dropped.

# %%
# Removing Subscription Id and Bike Id
data_merged.drop(['Subscription Id', 'Bike Id'], axis = 1, inplace = True)

# %%
# View the merged dataset
data_merged.head()
# Out:
#          Trip Id  Trip Duration  Start Station Id                Start Time  \
# 0         712441            274            7006.0 2017-01-01 00:00:00-05:00
# 90955     712439            453            7026.0 2017-01-01 00:00:00-05:00
# 969587    712445            645            7076.0 2017-01-01 00:00:00-05:00
# 1453301   712431            494            7163.0 2017-01-01 00:00:00-05:00
# 1453302   712432            425            7163.0 2017-01-01 00:00:00-05:00
#
#                       Start Station Name  End Station Id  \
# 0        Bay St / College St (East Side)          7021.0
# 90955             Bay St / St. Joseph St          7027.0
# 969587           York St / Queens Quay W          7010.0
# 1453301               Yonge St / Wood St          7634.0
# 1453302               Yonge St / Wood St          7634.0
#
#                          End Time                           End Station Name  \
# 0       2017-01-01 00:08:00-05:00                         Bay St / Albert St
# 90955   2016-12-31 23:58:00-05:00                 Beverley  St / Dundas St W
# 969587  2017-01-01 00:25:00-05:00                    King St W / Spadina Ave
# 1453301 2016-12-31 23:51:00-05:00  University Ave / Gerrard St W (West Side)
# 1453302 2016-12-31 23:50:00-05:00  University Ave / Gerrard St W (West Side)
#
#         User Type  Start_lat  ...  End_capacity  Temp (°C)  \
# 0          Member  43.660439  ...            35        1.5
# 90955      Member  43.665527  ...            31        1.5
# 969587     Member  43.640132  ...            19        1.5
# 1453301    Member  43.662222  ...            18        1.5
# 1453302    Member  43.662222  ...            18        1.5
#
#          Dew Point Temp (°C)  Rel Hum (%)  Wind Dir (10s deg)  \
# 0                       -3.6         69.0                26.0
# 90955                   -3.6         69.0                26.0
# 969587                  -3.6         69.0                26.0
# 1453301                 -3.6         69.0                26.0
# 1453302                 -3.6         69.0                26.0
#
#          Wind Spd (km/h)  Visibility (km)  Hmdx  Wind Chill  Weather
# 0                   39.0             16.1   NaN         NaN    Clear
# 90955               39.0             16.1   NaN         NaN    Clear
# 969587              39.0             16.1   NaN         NaN    Clear
# 1453301             39.0             16.1   NaN         NaN    Clear
# 1453302             39.0             16.1   NaN         NaN    Clear
#
# [5 rows x 24 columns]

# %%
# View the size of the merged dataset
data_merged.shape
# Out:
# (8007533, 24)

# %%
# View the columns of the merged dataset
data_merged.columns
# Out:
# Index(['Trip Id', 'Trip Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'User Type', 'Start_lat', 'Start_lon', 'Start_capacity', 'End_lat',
#        'End_lon', 'End_capacity', 'Temp (°C)', 'Dew Point Temp (°C)',
#        'Rel Hum (%)', 'Wind Dir (10s deg)', 'Wind Spd (km/h)',
#        'Visibility (km)', 'Hmdx', 'Wind Chill', 'Weather'],
#       dtype='object')

# %%
# Check missing values
data_merged.isnull().sum()
# Out:
# Trip Id                      0
# Trip Duration                0
# Start Station Id             0
# Start Time                   0
# Start Station Name           0
# End Station Id               0
# End Time                     0
# End Station Name             0
# User Type                    0
# Start_lat                    0
# Start_lon                    0
# Start_capacity               0
# End_lat                      0
# End_lon                      0
# End_capacity                 0
# Temp (°C)                    0
# Dew Point Temp (°C)          0
# Rel Hum (%)                  0
# Wind Dir (10s deg)           0
# Wind Spd (km/h)              0
# Visibility (km)              0
# Hmdx                   5150869
# Wind Chill             7578765
# Weather                      0
# dtype: int64

# %% [markdown]
# # Summary
# In summary, the final merged dataset is accomplished. It has 8007533 data points and 24 columns which can be seen as above. Furthermore, the missing values have been cleaned except for Humidex and Wind Chill columns for reasons explained above.

# %%
# Export the final data set as CSV
data_merged.to_csv('data_merged.csv')
